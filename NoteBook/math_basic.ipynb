# %% [markdown]
# 2025/12/01
# Although this note was not written at the first day, but I place it at the beginning as a summary of mathmetical fundation of quantum information.In this note I will explain the linear algebra, Pauli gates, Bloch Sphere.

# %% [markdown]
# # Linear algebra basics
# ## Bra-Ket notation
# Bra : $\langle 0|$, it's a row vector .Ket: $|1 \rangle$，it's a column vector.They are represented as follows.
# $$
# \langle 0| = \begin{pmatrix} 1 & 0 \end{pmatrix}
# \ \ , \ \
# |1 \rangle = \begin{pmatrix} 0 \\ 1 \end{pmatrix}
# $$
# ---
# ## Product
# ### Tensor product
# $$|a\rangle \otimes |b\rangle = |ab\rangle  , \langle a| \otimes \langle b| = \langle ab |\\$$
# If a=0,b=1,we can calculate the result as below:
# $$|01 \rangle =  \begin{pmatrix} 1 \\ 0 \end{pmatrix} \otimes \begin{pmatrix} 0 \\ 1 \end{pmatrix} = \begin{pmatrix} 1 \cdot \begin{pmatrix} 0 \\ 1 \end{pmatrix} \\ 0 \cdot \begin{pmatrix} 0 \\ 1 \end{pmatrix} \end{pmatrix} = \begin{pmatrix} 0 \\ 1 \\ 0 \\ 0 \end{pmatrix}$$
#
#
# if a=1,b=0, we can calculate the outcome of $\langle a| \otimes \langle b| = \langle ab |$ as below:
# Since $\langle ab |$ is the Hermetian conjugate of $|ab \rangle $ , we can first calculate $|ab \rangle $ and then take the adjoint.
#
#
# $$
# \langle 10| = (|10\rangle)^\dagger = \begin{pmatrix} 0 \\ 0 \\ 1 \\ 0 \end{pmatrix}^\dagger = \begin{pmatrix} 0 & 0 & 1 & 0 \end{pmatrix}
# $$
#
#
# ### Inner product(Scalar product) and outer product
# It's straightforward to understand why the inner product yields a scalar while the outer yields a  matrix.
# $$\langle a|b \rangle  = \delta_{ab} $$
# $$ |a\rangle\langle b| = \begin{pmatrix} x & y  \\ z & w \end{pmatrix} $$
#
#
# ## Two qubits represent
